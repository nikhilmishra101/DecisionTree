# %%
# Importing Libraries
import pydotplus
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
#Loading Dataset
iris = datasets.load_iris()
#random state=1 means that the split of data will always be same means same data points on training and testing
x_train,x_test,y_train,y_test = train_test_split(iris.data,iris.target,random_state=1)

# %%
#Training Classifier
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
#Exporting Decision tree into pdf
dot_data = export_graphviz(clf,out_file=None,feature_names=iris.feature_names,class_names=iris.target_names) #out_file means in which file this dot data needs to saved if it's going to saved in a variable or no file then out_file = None
graph = pydotplus.graph_from_dot_data(dot_data) #return graph object
graph.write_pdf("iris.pdf")
# Out:
# True

# %%
#Predicting on training and testing data
y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(x_test)

# %%
#confusion Matrix on training data
confusion_matrix(y_train,y_train_pred)
# Out:
# array([[37,  0,  0],
#        [ 0, 34,  0],
#        [ 0,  0, 41]])

# %%
#confusion Matrix on testing data
confusion_matrix(y_test,y_test_pred)
# Out:
# array([[13,  0,  0],
#        [ 0, 15,  1],
#        [ 0,  0,  9]])
